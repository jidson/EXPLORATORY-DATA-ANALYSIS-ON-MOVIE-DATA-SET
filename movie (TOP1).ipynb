# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #	Load data

# %%
movies_data= pd.read_csv(r'C:\Users\JIDSON\Desktop\PROJECT 2023-2024\Data Class\imdb_top_1000.csv')

# %%
movies_data.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %%
movies_data.tail(5)
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
movies_data.shape
# Out:
# (1000, 16)

# %%
movies_data.rename(columns = {"Series_Title": "Movie_Title"}, inplace=True)

# %%
movies_data.head(3)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                 Movie_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
movies_data.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
movies_data.describe(include='all')
# Out:
#                                               Poster_Link Movie_Title  \
# count                                                1000        1000
# unique                                               1000         999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...    Drishyam
# freq                                                    1           2
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# count           1000         899     1000   1000  1000.000000
# ...

# %% [markdown]
# # Data Cleaning

# %%
movies_data.isna().sum()
# Out:
# Poster_Link        0
# Movie_Title        0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
movies_data[['Certificate']].dtypes
# Out:
# Certificate    object
# dtype: object

# %%
movies_data[['Meta_score']].dtypes
# Out:
# Meta_score    float64
# dtype: object

# %%
movies_data[['Gross']].dtypes
# Out:
# Gross    object
# dtype: object

# %% [markdown]
# **Cleaning the metascore column**

# %%
movies_data[['Meta_score']]
# Out:
#      Meta_score
# 0          80.0
# 1         100.0
# 2          84.0
# 3          90.0
# 4          96.0
# ..          ...
# 995        76.0
# 996        84.0
# 997        85.0
# 998        78.0
# 999        93.0
#
# [1000 rows x 1 columns]

# %%
movies_data[['Meta_score']].isna().sum()
# Out:
# Meta_score    157
# dtype: int64

# %%
meta_mean=movies_data['Meta_score'].mean()
print(meta_mean)
Meta_score=movies_data[['Meta_score']].fillna(meta_mean)
Meta_score
# Out:
# 77.97153024911032
#      Meta_score
# 0          80.0
# 1         100.0
# 2          84.0
# 3          90.0
# 4          96.0
# ..          ...
# 995        76.0
# 996        84.0
# 997        85.0
# 998        78.0
# 999        93.0
#
# [1000 rows x 1 columns]

# %%
movies_data['Meta_score']=Meta_score

# %%
movies_data['Meta_score'].isna().sum()
# Out:
# 0

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# **Cleaning the Certificate column**

# %%
movies_data['Certificate'].isna().sum()
# Out:
# 101

# %%
movies_data['Certificate'].fillna('None',inplace=True)
# Out:
# C:\Users\JIDSON\AppData\Local\Temp\ipykernel_6660\3779983518.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   movies_data['Certificate'].fillna('None',inplace=True)

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
movies_data['Certificate']
# Out:
# 0           A
# 1           A
# 2          UA
# 3           A
# 4           U
#         ...
# 995         A
# 996         G
# 997    Passed
# 998      None
# 999      None
# Name: Certificate, Length: 1000, dtype: object

# %% [markdown]
# **Cleaning the Gross  column**

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
movies_data[['Gross']]
# Out:
#            Gross
# 0     28,341,469
# 1    134,966,411
# 2    534,858,444
# 3     57,300,000
# 4      4,360,000
# ..           ...
# 995          NaN
# 996          NaN
# 997   30,500,000
# 998          NaN
# 999          NaN
#
# [1000 rows x 1 columns]

# %%
movies_data[['Gross']].dtypes
# Out:
# Gross    object
# dtype: object

# %%
grossdata=movies_data['Gross'].str.replace(',','')
grossdata
# Out:
# 0       28341469
# 1      134966411
# 2      534858444
# 3       57300000
# 4        4360000
#          ...
# 995          NaN
# 996          NaN
# 997     30500000
# 998          NaN
# 999          NaN
# Name: Gross, Length: 1000, dtype: object

# %%
movies_data['Gross']=grossdata

# %%
movies_data['Gross']= movies_data['Gross'].map(lambda X:float(X))

# %%
movies_data['Gross'].dtype
# Out:
# dtype('float64')

# %%
movies_data['Gross']
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995            NaN
# 996            NaN
# 997     30500000.0
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Movie_Title    1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    1000 non-null   object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 125.1+ KB

# %%
movies_data['Gross'].isna().sum()
# Out:
# 169

# %%
# gross_mean=movies_data['Gross'].mean()

# movies_data.fillna(gross_mean,inplace=True)

# %%
movies_data.dropna(inplace=True)

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 831 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    831 non-null    object
#  1   Movie_Title    831 non-null    object
#  2   Released_Year  831 non-null    object
#  3   Certificate    831 non-null    object
#  4   Runtime        831 non-null    object
#  5   Genre          831 non-null    object
#  6   IMDB_Rating    831 non-null    float64
#  7   Overview       831 non-null    object
#  8   Meta_score     831 non-null    float64
#  9   Director       831 non-null    object
#  10  Star1          831 non-null    object
#  11  Star2          831 non-null    object
#  12  Star3          831 non-null    object
#  13  Star4          831 non-null    object
#  14  No_of_Votes    831 non-null    int64
#  15  Gross          831 non-null    float64
# dtypes: float64(3), int64(1), object(12)
# memory usage: 110.4+ KB

# %%
movies_data.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes         Gross
# count   831.000000  831.000000  8.310000e+02  8.310000e+02
# mean      7.946931   77.509860  3.152499e+05  6.803475e+07
# std       0.283204   11.869645  3.436443e+05  1.097500e+08
# min       7.600000   28.000000  2.508800e+04  1.305000e+03
# 25%       7.700000   71.000000  7.143000e+04  3.253559e+06
# 50%       7.900000   77.971530  1.867340e+05  2.353089e+07
# 75%       8.100000   85.500000  4.457210e+05  8.075089e+07
# max       9.300000  100.000000  2.343110e+06  9.366622e+08

# %% [markdown]
# # Exploratory Data Analysis

# %%
movies_data.columns
# Out:
# Index(['Poster_Link', 'Movie_Title', 'Released_Year', 'Certificate', 'Runtime',
#        'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
movies_data.set_index('Movie_Title',inplace=True)

# %%
movies_data
# Out:
#                                                                 Poster_Link  \
# Movie_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Giù la testa              https://m.media-amazon.com/images/M/MV5BYjRmY2...
# Kelly's Heroes            https://m.media-amazon.com/images/M/MV5BMzAyND...
# The Jungle Book           https://m.media-amazon.com/images/M/MV5BMjAwMT...
# A Hard Day's Night        https://m.media-amazon.com/images/M/MV5BZjQyMG...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
# ...

# %% [markdown]
# **what is the title of the top-rated movie in the IMDb rating dataset, and what is its IMDb rating?**

# %%
movies_data['IMDB_Rating'].sort_values(ascending=False)[:1]
# Out:
# Movie_Title
# The Shawshank Redemption    9.3
# Name: IMDB_Rating, dtype: float64

# %% [markdown]
# **observation**
# **The top rated movie is the dataset i The Shawshank Redemption with rating  9.3**

# %% [markdown]
# **Additionally, could you provide insights into the genre, director, main cast, release year, and runtime of the top-rated movie?**

# %%
movies_data[['IMDB_Rating','Director','Released_Year','Genre','Star1','Runtime',]].sort_values(by='IMDB_Rating',ascending=False)[:1]
# Out:
#                           IMDB_Rating        Director Released_Year  Genre  \
# Movie_Title
# The Shawshank Redemption          9.3  Frank Darabont          1994  Drama
#
#                                 Star1  Runtime
# Movie_Title
# The Shawshank Redemption  Tim Robbins  142 min

# %% [markdown]
# **Which movie has received the highest number of votes from IMDb users?**

# %%
movies_data['No_of_Votes'].sort_values(ascending=False)[:5]
# Out:
# Movie_Title
# The Shawshank Redemption    2343110
# The Dark Knight             2303232
# Inception                   2067042
# Fight Club                  1854740
# Pulp Fiction                1826188
# Name: No_of_Votes, dtype: int64

# %% [markdown]
# **Who are the top 5 directors in terms of average IMDb rating for their movies?**

# %%
movies_data[['IMDB_Rating', 'Director']]
# Out:
#                           IMDB_Rating              Director
# Movie_Title
# The Shawshank Redemption          9.3        Frank Darabont
# The Godfather                     9.2  Francis Ford Coppola
# The Dark Knight                   9.0     Christopher Nolan
# The Godfather: Part II            9.0  Francis Ford Coppola
# 12 Angry Men                      9.0          Sidney Lumet
# ...                               ...                   ...
# Giù la testa                      7.6          Sergio Leone
# Kelly's Heroes                    7.6       Brian G. Hutton
# The Jungle Book                   7.6   Wolfgang Reitherman
# A Hard Day's Night                7.6        Richard Lester
# From Here to Eternity             7.6        Fred Zinnemann
#
# [831 rows x 2 columns]

# %% [markdown]
# **Which director has the highest average rating?**

# %%
movies_data[['IMDB_Rating', 'Director']].sort_values(by='IMDB_Rating',ascending=False)[:1]
# Out:
#                           IMDB_Rating        Director
# Movie_Title
# The Shawshank Redemption          9.3  Frank Darabont

# %%
movies_data[['IMDB_Rating', 'Director']].sort_values(by='IMDB_Rating',ascending=False)[:5]
# Out:
#                           IMDB_Rating              Director
# Movie_Title
# The Shawshank Redemption          9.3        Frank Darabont
# The Godfather                     9.2  Francis Ford Coppola
# The Dark Knight                   9.0     Christopher Nolan
# The Godfather: Part II            9.0  Francis Ford Coppola
# 12 Angry Men                      9.0          Sidney Lumet

# %% [markdown]
# **Get the numbers movies released from the years 2005 to 2014**

# %%
movies_data['Released_Year'].sort_values(ascending=False)
# Out:
# Movie_Title
# Apollo 13                 PG
# Knives Out              2019
# Jojo Rabbit             2019
# Toy Story 4             2019
# Marriage Story          2019
#                         ...
# The General             1926
# Bronenosets Potemkin    1925
# The Gold Rush           1925
# Sherlock Jr.            1924
# The Kid                 1921
# Name: Released_Year, Length: 831, dtype: object

# %%
movies_between_2005_2015 = movies_data[(movies_data['Released_Year'] >='2005') & (movies_data['Released_Year'] <='2015')]
movies_between_2005_2015
# Out:
#                                                             Poster_Link  \
# Movie_Title
# The Dark Knight       https://m.media-amazon.com/images/M/MV5BMTMxNT...
# Inception             https://m.media-amazon.com/images/M/MV5BMjAxMz...
# Interstellar          https://m.media-amazon.com/images/M/MV5BZjdkOT...
# Whiplash              https://m.media-amazon.com/images/M/MV5BOTA5ND...
# The Intouchables      https://m.media-amazon.com/images/M/MV5BMTYxND...
# ...                                                                 ...
# 300                   https://m.media-amazon.com/images/M/MV5BNWMxYT...
# Match Point           https://m.media-amazon.com/images/M/MV5BMjRjOT...
# Watchmen              https://m.media-amazon.com/images/M/MV5BY2IzNG...
# Lord of War           https://m.media-amazon.com/images/M/MV5BMTYzZW...
# Synecdoche, New York  https://m.media-amazon.com/images/M/MV5BMjA0Mj...
#
#                      Released_Year Certificate  Runtime  \
# Movie_Title
# ...

# %%
movies_between_2005_2015.sort_values(by = 'Released_Year', ascending=True)
# Out:
#                                                                                   Poster_Link  \
# Movie_Title
# Walk the Line                               https://m.media-amazon.com/images/M/MV5BMjIyOT...
# V for Vendetta                              https://m.media-amazon.com/images/M/MV5BOTI5OD...
# Joyeux Noël                                 https://m.media-amazon.com/images/M/MV5BMTQyOD...
# Black                                       https://m.media-amazon.com/images/M/MV5BNTI5Mm...
# Brokeback Mountain                          https://m.media-amazon.com/images/M/MV5BMTY5NT...
# ...                                                                                       ...
# Talvar                                      https://m.media-amazon.com/images/M/MV5BMTYzOD...
# Mustang                                     https://m.media-amazon.com/images/M/MV5BMTkwOD...
# Bridge of Spies                             https://m.media-amazon.com/images/M/MV5BMjIxOT...
# ...

# %%
movies_data.set_index('Movie_Title',inplace=True)

# %%
movies_data.shape
# Out:
# (1000, 15)

# %%
movies_data.head()
# Out:
#                                                                 Poster_Link  \
# Movie_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                          Released_Year Certificate  Runtime  \
# Movie_Title
# The Shawshank Redemption          1994           A  142 min
# The Godfather                     1972           A  175 min
# The Dark Knight                   2008          UA  152 min
# The Godfather: Part II            1974           A  202 min
# 12 Angry Men                      1957           U   96 min
#
#                                          Genre  IMDB_Rating  \
# Movie_Title
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, The Shawshank Redemption to The 39 Steps
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    1000 non-null   object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Overview       1000 non-null   object
#  7   Meta_score     1000 non-null   float64
#  8   Director       1000 non-null   object
#  9   Star1          1000 non-null   object
#  10  Star2          1000 non-null   object
#  11  Star3          1000 non-null   object
#  12  Star4          1000 non-null   object
#  13  No_of_Votes    1000 non-null   int64
#  14  Gross          1000 non-null   float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 125.0+ KB

# %%
movies_data['IMDB_Rating'].sort_values(ascending=False)[:10]
# Out:
# Movie_Title
# The Shawshank Redemption                             9.3
# The Godfather                                        9.2
# The Dark Knight                                      9.0
# The Godfather: Part II                               9.0
# 12 Angry Men                                         9.0
# The Lord of the Rings: The Return of the King        8.9
# Pulp Fiction                                         8.9
# Schindler's List                                     8.9
# The Lord of the Rings: The Fellowship of the Ring    8.8
# Forrest Gump                                         8.8
# Name: IMDB_Rating, dtype: float64

# %% [markdown]
# ***Answer: The title of the top rated movie is The Shawshank Redemption with a rating of 9.3***

# %% [markdown]
# **Additionally, could you provide insights into the genre, director, main cast, release year, and runtime of the top-rated movie?**

# %%
movies_data.loc['The Shawshank Redemption']
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BMDFkYT...
# Released_Year                                                 1994
# Certificate                                                      A
# Runtime                                                    142 min
# Genre                                                        Drama
# IMDB_Rating                                                    9.3
# Overview         Two imprisoned men bond over a number of years...
# Meta_score                                                    80.0
# Director                                            Frank Darabont
# Star1                                                  Tim Robbins
# Star2                                               Morgan Freeman
# Star3                                                   Bob Gunton
# Star4                                               William Sadler
# No_of_Votes                                                2343110
# ...

# %%
toprated=pd.DataFrame(movies_data.loc['The Shawshank Redemption']).T

# %%
toprated
# Out:
#                                                                 Poster_Link  \
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                          Released_Year Certificate  Runtime  Genre  \
# The Shawshank Redemption          1994           A  142 min  Drama
#
#                          IMDB_Rating  \
# The Shawshank Redemption         9.3
#
#                                                                    Overview  \
# The Shawshank Redemption  Two imprisoned men bond over a number of years...
#
#                          Meta_score        Director        Star1  \
# The Shawshank Redemption       80.0  Frank Darabont  Tim Robbins
#
#                                    Star2       Star3           Star4  \
# The Shawshank Redemption  Morgan Freeman  Bob Gunton  William Sadler
#
#                          No_of_Votes       Gross
# The Shawshank Redemption     2343110  28341469.0

# %%
toprated['Genre']
# Out:
# The Shawshank Redemption    Drama
# Name: Genre, dtype: object

# %%
toprated['Director']
# Out:
# The Shawshank Redemption    Frank Darabont
# Name: Director, dtype: object

# %%
toprated['Star1']
# Out:
# The Shawshank Redemption    Tim Robbins
# Name: Star1, dtype: object

# %%
toprated['Released_Year']
# Out:
# The Shawshank Redemption    1994
# Name: Released_Year, dtype: object

# %%
toprated['Runtime']
# Out:
# The Shawshank Redemption    142 min
# Name: Runtime, dtype: object

# %% [markdown]
# **Which movie has received the highest number of votes from IMDb users?**

# %%
movies_data
# Out:
#                                                                 Poster_Link  \
# Movie_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Breakfast at Tiffany's    https://m.media-amazon.com/images/M/MV5BNGEwMT...
# Giant                     https://m.media-amazon.com/images/M/MV5BODk3Yj...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# Lifeboat                  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# The 39 Steps              https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
# ...

# %%
movies_data['No_of_Votes'].sort_values(ascending=False)[:5]
# Out:
# Movie_Title
# The Shawshank Redemption    2343110
# The Dark Knight             2303232
# Inception                   2067042
# Fight Club                  1854740
# Pulp Fiction                1826188
# Name: No_of_Votes, dtype: int64

# %% [markdown]
# **Observation**

# %% [markdown]
# The Shawshank Redemptio movie has received the highest number of votes from IMDb users with  total votes of  2343110

# %%
movies_data[['IMDB_Rating','Director']].sort_values(by='IMDB_Rating',ascending=False)[:5]
# Out:
#                           IMDB_Rating              Director
# Movie_Title
# The Shawshank Redemption          9.3        Frank Darabont
# The Godfather                     9.2  Francis Ford Coppola
# The Dark Knight                   9.0     Christopher Nolan
# The Godfather: Part II            9.0  Francis Ford Coppola
# 12 Angry Men                      9.0          Sidney Lumet

# %%
movies_data[['IMDB_Rating','Director']].sort_values(by='IMDB_Rating',ascending=False)[:1]
# Out:
#                           IMDB_Rating        Director
# Movie_Title
# The Shawshank Redemption          9.3  Frank Darabont

# %%
movies_data[['Gross','Director']].sort_values(by='Gross',ascending=False)[:5]
# Out:
#                                                   Gross       Director
# Movie_Title
# Star Wars: Episode VII - The Force Awakens  936662225.0    J.J. Abrams
# Avengers: Endgame                           858373000.0  Anthony Russo
# Avatar                                      760507625.0  James Cameron
# Avengers: Infinity War                      678815482.0  Anthony Russo
# Titanic                                     659325379.0  James Cameron

# %%
movies_data['No_of_Votes'].sort_values(ascending=False)[:7]
# Out:
# Movie_Title
# The Shawshank Redemption    2343110
# The Dark Knight             2303232
# Inception                   2067042
# Fight Club                  1854740
# Pulp Fiction                1826188
# Forrest Gump                1809221
# The Matrix                  1676426
# Name: No_of_Votes, dtype: int64

# %%
No_of_Votes=movies_data['No_of_Votes'].sort_values(ascending=False)[:7]
No_of_Votes
# Out:
# Movie_Title
# The Shawshank Redemption    2343110
# The Dark Knight             2303232
# Inception                   2067042
# Fight Club                  1854740
# Pulp Fiction                1826188
# Forrest Gump                1809221
# The Matrix                  1676426
# Name: No_of_Votes, dtype: int64

# %%
plt.figure(figsize=(14,3))
plt.bar(x=No_of_Votes.index,height=No_of_Votes)
plt.show()

# %%
movies_data.columns
# Out:
# Index(['Poster_Link', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
top_rated_movies=movies_data[['IMDB_Rating','Gross']].sort_values(by='IMDB_Rating',ascending=False)[:7]
top_rated_movies
# Out:
#                                                IMDB_Rating        Gross
# Movie_Title
# The Shawshank Redemption                               9.3   28341469.0
# The Godfather                                          9.2  134966411.0
# The Dark Knight                                        9.0  534858444.0
# The Godfather: Part II                                 9.0   57300000.0
# 12 Angry Men                                           9.0    4360000.0
# The Lord of the Rings: The Return of the King          8.9  377845905.0
# Pulp Fiction                                           8.9  107928762.0

# %%
plt.figure(figsize=(24,12))
plt.bar(x=top_rated_movies.index,height=top_rated_movies['Gross'],data=movies_data)
plt.show()

# %%
plt.figure(figsize=(24,12))
plt.bar(x=top_rated_movies.index,height=top_rated_movies['Gross'],data=movies_data)
plt.show()
